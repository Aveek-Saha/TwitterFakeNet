# %%
text = ""

# %%
with open('datasets/unverified.dat', 'r',  encoding='utf8') as file:
    data = file.read()
    print(data)
    text += ''.join([i if ord(i) < 128 else '' for i in data])
# Out:
# 4A,https://pbs.twimg.com/profile_images/992186790051229697/NX375we3_normal.jpg,Brooklyn
# 54300359,#InternetBillOfRights❌,friends,1005,1055,89,183312,Mon Jul 06 19:10:19 +0000 2009,https://t.co/vmdfQetosM,https://pbs.twimg.com/profile_images/615335092987297792/vHYdT-PO_normal.jpg,Multi-Verse
# 260406732,PRODoBOTS...,friends,1753,1055,10,95051,Thu Mar 03 20:45:21 +0000 2011,http://t.co/E7eNXYKbxs,https://pbs.twimg.com/profile_images/1843567073/robot_pic_normal.jpg,miami * manhattan * la * uae
# 766267501,Rainy Day Couture,friends,1000,1054,58,116004,Sat Aug 18 19:35:42 +0000 2012,http://t.co/XtGHDyuS3L,https://pbs.twimg.com/profile_images/2532629053/o4jejv3hvu0rd9k8m8o6_normal.jpeg,Worldwide
# 3020115666,Opine⚕️HEALTH,friends,842,1054,273,271834,Sat Feb 14 21:43:55 +0000 2015,,https://pbs.twimg.com/profile_images/721121213859307521/TqeG9q9g_normal.jpg,
# ...

# %%
print(text)
# Out:
# ds,1898,1056,52,127556,Mon Apr 13 00:00:05 +0000 2009,https://t.co/ijrfjgxd4A,https://pbs.twimg.com/profile_images/992186790051229697/NX375we3_normal.jpg,Brooklyn
# 54300359,#InternetBillOfRights,friends,1005,1055,89,183312,Mon Jul 06 19:10:19 +0000 2009,https://t.co/vmdfQetosM,https://pbs.twimg.com/profile_images/615335092987297792/vHYdT-PO_normal.jpg,Multi-Verse
# 260406732,PRODoBOTS...,friends,1753,1055,10,95051,Thu Mar 03 20:45:21 +0000 2011,http://t.co/E7eNXYKbxs,https://pbs.twimg.com/profile_images/1843567073/robot_pic_normal.jpg,miami * manhattan * la * uae
# 766267501,Rainy Day Couture,friends,1000,1054,58,116004,Sat Aug 18 19:35:42 +0000 2012,http://t.co/XtGHDyuS3L,https://pbs.twimg.com/profile_images/2532629053/o4jejv3hvu0rd9k8m8o6_normal.jpeg,Worldwide
# 3020115666,OpineHEALTH,friends,842,1054,273,271834,Sat Feb 14 21:43:55 +0000 2015,,https://pbs.twimg.com/profile_images/721121213859307521/TqeG9q9g_normal.jpg,
# ...

# %%
text_file = open("unverified_ascii.dat", "w")
text_file.write(text)
text_file.close()
